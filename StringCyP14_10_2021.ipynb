# %%
carrera = "ingenieria en computacion"
print( carrera[8] )
print( carrera[24])
print( carrera[-1])
print( carrera[-25])



#Adelantado el tema ciclo POR

for letra in carrera:
  print( "-->",letra ,"<--")

cerrera = "ingenieria en computacion"
print(carrera[0:10:1])
print( carrera[14:25:1])
# lo mismo pero indexado negativo ??
print(carrera[-11:-1:1])
print(carrera[:10:])
print(carrera[14:25:])
print(carrera[-11::1])


# SOLUCION PREVIA
print("-------")
print( carrera[-11:-1:1])
print(carrera[ -11: :1])

frutas = "limon , fresa, manzana , aguacate "
nombre= "jose"
print(frutas)
dir(frutas)

print( nombre.capitalize() )
print( nombre.upper() )
print( frutas,replace( "a" ,"4") ).replace("e" ,"3").upper() )
print(frutas)
print(".-.-.-.-.-.-.-.-.-.-.-.-.-..-.-.-.")
frutas _ " limon , fresa, mazana ,aguacate "
print( frutas.strip() )
print( frutas.split(",") )

print("/"jose/"")
nombre="\"jose\""
print( nombre)
carrera = "ingenieria \n\ten "
# Out:
#   File "<ipython-input-22-29ce1a646dc9>", line 36
#     print( frutas,replace( "a" ,"4") ).replace("e" ,"3").upper() )
#                                                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# # String y sus metodos
# # Todos los tipos de phyton son objetos (CLASES de la PC0)
# ##dir () y help() funciones para obtener ayuda del leng

# %% [markdown]
# #Slicing (rebanado) de cadenas
# Permite seleccionar subcadenas con el operador
# #### [ inicio :stop :fin]

# %% [markdown]
# # a la sintaxis escrita para elegir un elemnto de un frupo de datos se le llama seelector
#
# En el caso de Strings y listas (list) se usasn los caracteres "[ y ]"
#
# 1. En todos los lenguajes los arreglos inician en 0
# 2. En python no exxiste como tal el tipo de dato arreglo,,elconcepto es sustituido por las listas
# 3. Los strings se comportan como un arreglo en la mayoriade los lenguajes
# 4. En python se acepta en indexado negativo, en otros lenguajes no
